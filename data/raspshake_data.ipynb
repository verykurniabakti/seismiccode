# %%
from obspy.clients.fdsn import Client
from obspy import UTCDateTime

client = Client("RASPISHAKE")

start = UTCDateTime("2020-01-01T00:00:00")
end = start + 600

try:
    st = client.get_waveforms("AM", "R24FA", "00", "EHZ", start, end)
    st.plot()
except Exception as e:
    print("Error:", e)

# %%
from obspy.clients.fdsn import Client
from obspy import UTCDateTime
start_1 = "2020-01-01 00:00:00"
starttime = UTCDateTime(start_1)
endtime = starttime + 600       # 600 seconds
client = Client(base_url='https://data.raspberryshake.org/')
waveform = client.get_waveforms('AM', 'R24FA', '00', 'EHZ', starttime, endtime)

# %%
from obspy.clients.fdsn import Client
client = Client('RASPISHAKE')
metadata = client.get_stations(network='AM', station='R24FA', location='00', channel='EHZ', level='RESP')

# %%
from obspy.clients.fdsn import Client
client = Client(base_url='https://data.raspberryshake.org/')
metadata = client.get_stations(network='AM', station='R24FA', location='00', channel='EHZ', level='RESP')

# %%
from obspy.clients.fdsn import Client
client = Client("RASPISHAKE")

inv = client.get_stations(network="AM", station="R24FA", level="channel")
print(inv)
# Out:
# Inventory created at 2026-03-03T07:56:54.414186Z
# 	Sending institution: SeisComP (RS)
# 	Contains:
# 		Networks (1):
# 			AM
# 		Stations (9):
# 			AM.R24FA (Raspberry Shake Citizen Science Station) (9x)
# 		Channels (36):
# 			AM.R24FA.00.EHZ (9x), AM.R24FA.00.ENZ (9x), AM.R24FA.00.ENN (9x),
# 			AM.R24FA.00.ENE (9x)

# %%
from obspy.clients.fdsn import Client
from obspy import UTCDateTime

client = Client("RASPISHAKE")

start = UTCDateTime("2023-09-01T00:00:00")  # sesuaikan dengan start_date
end = start + 600

try:
    st = client.get_waveforms("AM", "R24FA", "*", "*", start, end)
    st.plot()
except Exception as e:
    print("Error:", e)
# Out:
# Error: No data available for request.
# HTTP Status code: 204
# Detailed response of server:

# %%
from obspy.clients.fdsn import Client
from obspy import UTCDateTime

client = Client("RASPISHAKE")

station = "R66E3"  # ganti dengan kode stasiun Indonesia
start = UTCDateTime("2024-01-01T00:00:00")
end = start + 600  # 10 menit

st = client.get_waveforms("AM", station, "*", "*", start, end)
st.plot()

# %%
from obspy.clients.fdsn import Client
client = Client("RASPISHAKE")

inv = client.get_stations(network="AM", station="R8D56", level="channel")
print(inv)
inv = client.get_stations(network="AM", station="R8D56", level="station")
print(inv)
# Out:
# Inventory created at 2026-03-03T08:25:18.687446Z
# 	Sending institution: SeisComP (RS)
# 	Contains:
# 		Networks (1):
# 			AM
# 		Stations (3):
# 			AM.R8D56 (Raspberry Shake Citizen Science Station) (3x)
# 		Channels (12):
# 			AM.R8D56.00.EHZ (3x), AM.R8D56.00.ENZ (3x), AM.R8D56.00.ENN (3x),
# 			AM.R8D56.00.ENE (3x)
# Inventory created at 2026-03-03T08:25:19.817880Z
# 	Sending institution: SeisComP (RS)
# 	Contains:
# 		Networks (1):
# 			AM
# 		Stations (3):
# 			AM.R8D56 (Raspberry Shake Citizen Science Station) (3x)
# 		Channels (0):

# %%
from obspy.clients.fdsn import Client
from obspy import UTCDateTime

client = Client("RASPISHAKE")

network = "AM"
station = "R8D56"
location = "00"
channel = "EHZ"   # atau ENZ / ENN / ENE

# waktu hari ini (10 menit terakhir)
end = UTCDateTime()      # sekarang
start = end - 600        # 10 menit ke belakang

st = client.get_waveforms("AM", "R8D56", "00", "EH*", start, end)
st.plot()
# Out:
# ---------------------------------------------------------------------------
# FDSNNoDataException                       Traceback (most recent call last)
# Cell In[26], line 15
#      12 end = UTCDateTime()      # sekarang
#      13 start = end - 600        # 10 menit ke belakang
# ---> 15 st = client.get_waveforms("AM", "R8D56", "00", "EH*", start, end)
#      16 st.plot()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/seismic/lib/python3.10/site-packages/obspy/clients/fdsn/client.py:872, in Client.get_waveforms(self, network, station, location, channel, starttime, endtime, quality, minimumlength, longestonly, filename, attach_response, **kwargs)
#     867 url = self._create_url_from_parameters(
#     868     "dataselect", DEFAULT_PARAMETERS['dataselect'], kwargs)
#     870 # Gzip not worth it for MiniSEED and most likely disabled for this
#     871 # route in any case.
# --> 872 data_stream = self._download(url, use_gzip=False)
#     873 data_stream.seek(0, 0)
# ...

# %%
# data history dari stasiun R8D56 pada tanggal 1 Juni 2024 selama 10 menit Denpasar, Bali
from obspy.clients.fdsn import Client
from obspy import UTCDateTime

client = Client("RASPISHAKE")

start = UTCDateTime("2024-06-01T00:00:00")
end = start + 600  # 10 menit

#st = client.get_waveforms("AM", "R8D56", "00", "EHZ", start, end)
st = client.get_waveforms("AM", "R8D56", "00", "EH*", start, end) # Bali
#st = client.get_waveforms("AM", "S758F", "00", "EH*", start, end) # Yogyakarta
st.plot()
