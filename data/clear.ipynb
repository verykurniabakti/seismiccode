# %%
import os
import shutil
from pathlib import Path

print("🧹 Membersihkan semua cache Python, VS Code, TensorFlow, dan Keras...\n")

def remove_path(path):
    p = Path(path).expanduser()
    if p.exists():
        try:
            if p.is_dir():
                shutil.rmtree(p)
            else:
                p.unlink()
            print(f"🗑  Deleted: {p}")
        except Exception as e:
            print(f"⚠️  Cannot delete {p}: {e}")
    else:
        print(f"✔️  Skip (not found): {p}")

# 1. Hapus __pycache__ di project saat ini
print("🔍 Menghapus __pycache__ di project...")
for pycache in Path(".").rglob("__pycache__"):
    remove_path(pycache)

# 2. Hapus pip cache
print("\n🔍 Menghapus pip cache...")
remove_path("~/.cache/pip")
remove_path("~/Library/Caches/pip")

# 3. Hapus Python cache global
print("\n🔍 Menghapus Python cache global...")
remove_path("~/.cache/python")
remove_path("~/.cache/pypoetry")
remove_path("~/.cache/pipenv")

# 4. Hapus cache VS Code
print("\n🔍 Menghapus cache VS Code...")
remove_path("~/Library/Application Support/Code/Cache")
remove_path("~/Library/Application Support/Code/CachedData")
remove_path("~/Library/Application Support/Code/User/workspaceStorage")
remove_path("~/Library/Application Support/Code/Service Worker/CacheStorage")

# 5. Hapus cache Pylance
print("\n🔍 Menghapus cache Pylance...")
remove_path("~/Library/Application Support/Code/User/globalStorage/ms-python.vscode-pylance")

# 6. Hapus cache TensorFlow
print("\n🔍 Menghapus cache TensorFlow...")
remove_path("~/.cache/tensorflow")
remove_path("~/.cache/tfhub_modules")
remove_path("~/.cache/tfds")
remove_path("~/tensorflow_datasets")
remove_path("~/Library/Application Support/tensorflow")

# 7. Hapus cache Keras
print("\n🔍 Menghapus cache Keras...")
remove_path("~/.keras")
remove_path("~/Library/Application Support/keras")

# 8. Hapus cache ML umum
print("\n🔍 Menghapus cache ML umum (HuggingFace, PyTorch)...")
remove_path("~/.cache/huggingface")
remove_path("~/.cache/torch")

print("\n✨ Selesai! Semua cache berhasil dibersihkan.")
# Out:
# 🧹 Membersihkan semua cache Python, VS Code, TensorFlow, dan Keras...
#
# 🔍 Menghapus __pycache__ di project...
#
# 🔍 Menghapus pip cache...
# ✔️  Skip (not found): /Users/verykurniabakti/.cache/pip
# ✔️  Skip (not found): /Users/verykurniabakti/Library/Caches/pip
#
# 🔍 Menghapus Python cache global...
# ✔️  Skip (not found): /Users/verykurniabakti/.cache/python
# ✔️  Skip (not found): /Users/verykurniabakti/.cache/pypoetry
# ✔️  Skip (not found): /Users/verykurniabakti/.cache/pipenv
#
# 🔍 Menghapus cache VS Code...
# 🗑  Deleted: /Users/verykurniabakti/Library/Application Support/Code/Cache
# 🗑  Deleted: /Users/verykurniabakti/Library/Application Support/Code/CachedData
# 🗑  Deleted: /Users/verykurniabakti/Library/Application Support/Code/User/workspaceStorage
# ✔️  Skip (not found): /Users/verykurniabakti/Library/Application Support/Code/Service Worker/CacheStorage
#
# 🔍 Menghapus cache Pylance...
# ✔️  Skip (not found): /Users/verykurniabakti/Library/Application Support/Code/User/globalStorage/ms-python.vscode-pylance
#
# 🔍 Menghapus cache TensorFlow...
# ✔️  Skip (not found): /Users/verykurniabakti/.cache/tensorflow
# ✔️  Skip (not found): /Users/verykurniabakti/.cache/tfhub_modules
# ✔️  Skip (not found): /Users/verykurniabakti/.cache/tfds
# ✔️  Skip (not found): /Users/verykurniabakti/tensorflow_datasets
# ✔️  Skip (not found): /Users/verykurniabakti/Library/Application Support/tensorflow
#
# 🔍 Menghapus cache Keras...
# 🗑  Deleted: /Users/verykurniabakti/.keras
# ✔️  Skip (not found): /Users/verykurniabakti/Library/Application Support/keras
#
# 🔍 Menghapus cache ML umum (HuggingFace, PyTorch)...
# ✔️  Skip (not found): /Users/verykurniabakti/.cache/huggingface
# ✔️  Skip (not found): /Users/verykurniabakti/.cache/torch
#
# ✨ Selesai! Semua cache berhasil dibersihkan.

# %%
import os
import shutil
from pathlib import Path
import subprocess

print("🧹 Membersihkan cache & log untuk mengurangi System Data...\n")

def remove_path(path):
    p = Path(path).expanduser()
    if p.exists():
        try:
            if p.is_dir():
                shutil.rmtree(p)
            else:
                p.unlink()
            print(f"🗑  Deleted: {p}")
        except Exception as e:
            print(f"⚠️  Cannot delete {p}: {e}")
    else:
        print(f"✔️  Skip (not found): {p}")

# 1. Cache user-level
print("🔍 Menghapus cache user-level...")
user_cache = ["~/Library/Caches", "~/.cache"]
for base in user_cache:
    base_path = Path(base).expanduser()
    if base_path.exists():
        for item in base_path.iterdir():
            if item.name.startswith("com.apple.Safari") or item.name.startswith("CloudKit"):
                print(f"✔️  Skip (Apple core cache): {item}")
                continue
            remove_path(item)

# 2. Log user
print("\n🔍 Menghapus log user...")
remove_path("~/Library/Logs")

# 3. Log sistem non-kritis
print("\n🔍 Menghapus log sistem (butuh sudo saat menjalankan script)...")
try:
    subprocess.run(["sudo", "rm", "-rf", "/private/var/log/*"], check=False)
    print("🗑  Log sistem dibersihkan.")
except Exception as e:
    print(f"⚠️  Tidak bisa menghapus log sistem: {e}")

# 4. Cache aplikasi besar
print("\n🔍 Menghapus cache aplikasi besar...")
big_app_cache = [
    # Chrome
    "~/Library/Application Support/Google/Chrome/Default/Cache",
    "~/Library/Application Support/Google/Chrome/ShaderCache",
    "~/Library/Application Support/Google/Chrome/GrShaderCache",
    "~/Library/Application Support/Google/Chrome/Crashpad",

    # Edge
    "~/Library/Application Support/Microsoft Edge/Default/Cache",
    "~/Library/Application Support/Microsoft Edge/ShaderCache",
    "~/Library/Application Support/Microsoft Edge/GrShaderCache",
    "~/Library/Application Support/Microsoft Edge/Crashpad",

    # VS Code
    "~/Library/Application Support/Code/Cache",
    "~/Library/Application Support/Code/CachedData",
    "~/Library/Application Support/Code/User/workspaceStorage",
    "~/Library/Application Support/Code/Service Worker/CacheStorage",

    # Zoom
    "~/Library/Application Support/zoom.us/data",
    "~/Library/Application Support/zoom.us/logs",

    # Spotify
    "~/Library/Application Support/Spotify/PersistentCache",
]

for p in big_app_cache:
    remove_path(p)

# 5. Cache Python
print("\n🔍 Menghapus cache Python...")
remove_path("~/.cache/pip")
remove_path("~/.cache/python")

# 6. Cache TensorFlow & Keras
print("\n🔍 Menghapus cache TensorFlow & Keras...")
remove_path("~/.cache/tensorflow")
remove_path("~/.cache/tfds")
remove_path("~/tensorflow_datasets")
remove_path("~/.keras")

# 7. Cache ML umum
print("\n🔍 Menghapus cache ML umum...")
remove_path("~/.cache/huggingface")
remove_path("~/.cache/torch")

# 8. __pycache__ di project
print("\n🔍 Menghapus __pycache__ di project saat ini...")
for pycache in Path(".").rglob("__pycache__"):
    remove_path(pycache)

# 9. Tampilkan APFS snapshots
print("\n📸 APFS Local Snapshots (penyebab terbesar System Data):")
try:
    subprocess.run(["tmutil", "listlocalsnapshots", "/"])
    print("\nℹ️ Hapus snapshot dengan:")
    print("   sudo tmutil deletelocalsnapshots <nama-snapshot>")
except Exception as e:
    print(f"⚠️ Tidak bisa menampilkan snapshot: {e}")

print("\n✨ Selesai! Cache & log aman sudah dibersihkan.")
# Out:
# 🧹 Membersihkan cache & log untuk mengurangi System Data...
#
# 🔍 Menghapus cache user-level...
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.AvatarKit
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.appleaccountd
# ⚠️  Cannot delete /Users/verykurniabakti/Library/Caches/familycircled: [Errno 1] Operation not permitted: '/Users/verykurniabakti/Library/Caches/familycircled'
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.helpd
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/SentryCrash
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/GeoServices
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.managedappdistributionagent
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.storekitagent
# ⚠️  Cannot delete /Users/verykurniabakti/Library/Caches/com.apple.HomeKit: [Errno 1] Operation not permitted: '/Users/verykurniabakti/Library/Caches/com.apple.HomeKit'
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.proactive.eventtracker
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/PassKit
# ✔️  Skip (Apple core cache): /Users/verykurniabakti/Library/Caches/CloudKit
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.SoftwareUpdateNotificationManager
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.microsoft.VSCode.ShipIt
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.preferencepanes.usercache
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.akd
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.FeatureAccessAgent
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/conda
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/crashpad-handler
# ✔️  Skip (Apple core cache): /Users/verykurniabakti/Library/Caches/com.apple.Safari
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.microsoft.autoupdate.fba
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.Spotlight
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.siri.findmy.syncdevicedata.json
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.businessservicesd
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.appstoreagent
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.DictionaryServices
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.CloudTelemetry
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/INSTALLATION
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.geoanalyticsd
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.nbagent
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.tipsd
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.itunescloudd
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/flutter_engine
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.sirittsd
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.nsurlsessiond
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.VideoConference
# ⚠️  Cannot delete /Users/verykurniabakti/Library/Caches/com.apple.containermanagerd: [Errno 1] Operation not permitted: '/Users/verykurniabakti/Library/Caches/com.apple.containermanagerd'
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.systemsettings.menucache
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/AAProfilePicture_3BEE57A9-7595-47BE-BDF7-FC8F1056BB08.png
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.passd
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.chrono
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.siri.bundleservicecache.plist
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.AppleMediaServices
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.remindd
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.dataaccess.dataaccessd
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.python
# ✔️  Skip (Apple core cache): /Users/verykurniabakti/Library/Caches/com.apple.Safari.SafeBrowsing
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.parsecd
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.nsservicescache.plist
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.bird
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.microsoft.VSCode
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.amsaccountsd
# ⚠️  Cannot delete /Users/verykurniabakti/Library/Caches/FamilyCircle: [Errno 1] Operation not permitted: '/Users/verykurniabakti/Library/Caches/FamilyCircle'
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/Microsoft Edge
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.AMPLibraryAgent
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.commerce
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.feedbacklogger
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.sharekit.4024808128781873001.png
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/askpermissiond
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.duetexpertd
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.ap.PromotedContentJetService
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.iTunes
# ⚠️  Cannot delete /Users/verykurniabakti/Library/Caches/com.apple.homed: [Errno 1] Operation not permitted: '/Users/verykurniabakti/Library/Caches/com.apple.homed'
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/io.sentry
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.translationd
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.ctcategories.service
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.AuthenticationServicesCore.AuthenticationServicesAgent
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.iCloudNotificationAgent
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.cache_delete
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.tiswitcher.cache
# 🗑  Deleted: /Users/verykurniabakti/Library/Caches/com.apple.amsengagementd
# ⚠️  Cannot delete /Users/verykurniabakti/Library/Caches/com.apple.ap.adprivacyd: [Errno 1] Operation not permitted: '/Users/verykurniabakti/Library/Caches/com.apple.ap.adprivacyd'
#
# 🔍 Menghapus log user...
# ⚠️  Cannot delete /Users/verykurniabakti/Library/Logs: [Errno 13] Permission denied: '/Users/verykurniabakti/Library/Logs'
#
# 🔍 Menghapus log sistem (butuh sudo saat menjalankan script)...
# 🗑  Log sistem dibersihkan.
#
# 🔍 Menghapus cache aplikasi besar...
# ✔️  Skip (not found): /Users/verykurniabakti/Library/Application Support/Google/Chrome/Default/Cache
# ✔️  Skip (not found): /Users/verykurniabakti/Library/Application Support/Google/Chrome/ShaderCache
# ✔️  Skip (not found): /Users/verykurniabakti/Library/Application Support/Google/Chrome/GrShaderCache
# ✔️  Skip (not found): /Users/verykurniabakti/Library/Application Support/Google/Chrome/Crashpad
# ✔️  Skip (not found): /Users/verykurniabakti/Library/Application Support/Microsoft Edge/Default/Cache
# 🗑  Deleted: /Users/verykurniabakti/Library/Application Support/Microsoft Edge/ShaderCache
# 🗑  Deleted: /Users/verykurniabakti/Library/Application Support/Microsoft Edge/GrShaderCache
# 🗑  Deleted: /Users/verykurniabakti/Library/Application Support/Microsoft Edge/Crashpad
# ✔️  Skip (not found): /Users/verykurniabakti/Library/Application Support/Code/Cache
# ✔️  Skip (not found): /Users/verykurniabakti/Library/Application Support/Code/CachedData
# ✔️  Skip (not found): /Users/verykurniabakti/Library/Application Support/Code/User/workspaceStorage
# ✔️  Skip (not found): /Users/verykurniabakti/Library/Application Support/Code/Service Worker/CacheStorage
# ✔️  Skip (not found): /Users/verykurniabakti/Library/Application Support/zoom.us/data
# ✔️  Skip (not found): /Users/verykurniabakti/Library/Application Support/zoom.us/logs
# ✔️  Skip (not found): /Users/verykurniabakti/Library/Application Support/Spotify/PersistentCache
#
# 🔍 Menghapus cache Python...
# ✔️  Skip (not found): /Users/verykurniabakti/.cache/pip
# ✔️  Skip (not found): /Users/verykurniabakti/.cache/python
#
# 🔍 Menghapus cache TensorFlow & Keras...
# ✔️  Skip (not found): /Users/verykurniabakti/.cache/tensorflow
# ✔️  Skip (not found): /Users/verykurniabakti/.cache/tfds
# ✔️  Skip (not found): /Users/verykurniabakti/tensorflow_datasets
# ✔️  Skip (not found): /Users/verykurniabakti/.keras
#
# 🔍 Menghapus cache ML umum...
# ✔️  Skip (not found): /Users/verykurniabakti/.cache/huggingface
# ✔️  Skip (not found): /Users/verykurniabakti/.cache/torch
#
# 🔍 Menghapus __pycache__ di project saat ini...
#
# 📸 APFS Local Snapshots (penyebab terbesar System Data):
# Snapshots for disk /:
#
# ℹ️ Hapus snapshot dengan:
#    sudo tmutil deletelocalsnapshots <nama-snapshot>
#
# ✨ Selesai! Cache & log aman sudah dibersihkan.
# sudo: a terminal is required to read the password; either use the -S option to read from standard input or configure an askpass helper
# sudo: a password is required
