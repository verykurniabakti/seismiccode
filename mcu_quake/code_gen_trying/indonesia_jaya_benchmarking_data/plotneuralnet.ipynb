# %%
from pycore.tikzeng import *
arch = [
    to_Conv("conv1", 512, 64, offset="(0,0,0)", to="(0,0,0)", height=64, depth=64, width=2),
    to_Pool("pool1", offset="(0,0,0)", to="(conv1-east)"),
    to_connection("pool1", "conv2"),
    to_end()
]
to_generate(arch, 'my_net.tex')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pycore.tikzeng import *
#       2 arch = [
#       3     to_Conv("conv1", 512, 64, offset="(0,0,0)", to="(0,0,0)", height=64, depth=64, width=2),
#       4     to_Pool("pool1", offset="(0,0,0)", to="(conv1-east)"),
#       5     to_connection("pool1", "conv2"),
#       6     to_end()
#       7 ]
#       8 to_generate(arch, 'my_net.tex')
#
# ModuleNotFoundError: No module named 'pycore.tikzeng'
