# %%
# -*- coding: utf-8 -*- sesi 2
from Library import utils, dataset
import os
from tensorflow import keras
from tqdm import tqdm
import numpy as np
from datetime import datetime
import logging
import matplotlib.pyplot as plt

# Fungsi untuk membuat diagram batang metrik komprehensif
def plot_comprehensive_metrics(metrics, save_path):
    # Mapping nama label ke key yang tepat sesuai output Anda
    labels = ['Accuracy', 'Recall', 'Precision', 'FPR', 'F1-Score']
    keys = [
        'Accuracy (avg.)', 
        'True positive rate (avg.)', 
        'Positive predictive value (avg.)', 
        'False positive rate (avg.)', 
        'F1-score (avg.)'
    ]
    
    # Mengambil nilai berdasarkan key yang tepat
    values = [metrics.get(k, 0) for k in keys]
    
    print(f"[DEBUG] Nilai yang akan diplot: {values}") 

    plt.figure(figsize=(12, 6))
    bars = plt.bar(labels, values, color=['#2c3e50', '#3498db', '#e67e22', '#e74c3c', '#27ae60'])
    
    plt.ylim(0, 1.0)
    plt.ylabel('Score')
    plt.title('Performance Metrics Evaluation (Average)')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    
    # Tambahkan angka di atas batang
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 0.01,
                f'{height:.3f}', ha='center', va='bottom')
                
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    plt.close()
    print(f"[INFO] Grafik metrik komprehensif tersimpan di: {save_path}")

# Main execution
if __name__ == "__main__":


    #===================================================================
    #                    1. KONFIGURASI PATH STEAD
    #===================================================================
    # Path dataset STEAD yang Bapak berikan
    #KEY_DATA_DIR = '/Volumes/Extreme SSD/json_indonesia_juli_sesi_4'
    #KEY_TEST_FILE = 'extracted_data_3c_4.json'
    #KEY_TEST_FILE = 'extracted_data_3c_4_NOFILTER.json'
    #KEY_TEST_FILE = 'extracted_data_3c_4_CLEAN.json'
    #KEY_TEST_FILE = 'extracted_data_3c_4_final.json'
    KEY_DATA_DIR = "/Volumes/Extreme SSD/json_indonesia_juli_sesi_5"
    KEY_TEST_FILE = "extracted_data_3c_sesi_clean.json"



    DATA_TAG = "INDONESIA_DOMAIN"
    MODEL_TAG = "MCU_Quake_3C"
    INPUT_WIN = 7 
    SAMPLING_RATE = 100
    
    # STEAD fokus pada Noise (NO) dan Earthquake (LE)
    true_labels = ["NO", "LE"]
    source_to_code = {"noise": 0, "le": 1}

    # Path Model dan Embedding 
    BASE_REP = "/Volumes/Local Disk/Code_Git/S3_code/seismic/mcu_quake/code_gen_trying/indonesia_jaya_benchmarking_data/mulai_juli/mcquake_ori_file/Code & Figure demo"
    MODEL_PATH = os.path.join(BASE_REP, "Pre-trained model/MCU-Quake 5-20")
    
    # Path Embedding Khusus STEAD (n=61099) atau UUSS (n=11275) opsi: gunakan salah satu, jangan keduanya
    #EMB_DIR = os.path.join(BASE_REP, "Typical embedding/Embedding_data train 3C, STEAD norm7 mag3 L n61099, 30172538")
    #EMB_DIR = os.path.join(BASE_REP, "Typical embedding/Embedding_data train 3C, UUSS n11275 std15, 30120909")
    EMB_DIR = "/Volumes/Extreme SSD/unduhan_waveform_geofon/output/indonesia_domain_embeddings_3c_le"
    #===================================================================
    #                           2. PREPARE FILES
    #===================================================================
    print(f"[INFO] Memuat Dataset UUSS: {KEY_TEST_FILE}")
    test_data = dataset.load_json_data(os.path.join(KEY_DATA_DIR, KEY_TEST_FILE))
    
    SAVE_BASE = '/Volumes/Extreme SSD/json_indonesia_juli_sesi_5/output/nUUSS_embedding_3c_5a_final_clean'
    now = datetime.now()
    time_str = now.strftime("%d%H%M%S")
    save_dir = os.path.join(SAVE_BASE, f"{MODEL_TAG}_{DATA_TAG}_{time_str}")
    if not os.path.exists(save_dir): os.makedirs(save_dir)

    # Logger
    log_file_path = os.path.join(save_dir, "task_log_uuss_global.txt")
    logging.basicConfig(filename=log_file_path, level=logging.INFO, filemode='w',
                        format='%(asctime)s - [%(levelname)s]: %(message)s')
    logger = logging.getLogger()
    logger.addHandler(logging.StreamHandler())

    # Load Model & Embeddings STEAD
    embedding_model = keras.models.load_model(filepath=MODEL_PATH)
    embedding_Z = dataset.load_embedding_data(EMB_DIR, "Embedding data, Z.json")
    embedding_N = dataset.load_embedding_data(EMB_DIR, "Embedding data, N.json")
    embedding_E = dataset.load_embedding_data(EMB_DIR, "Embedding data, E.json")

    logger.info(f"Estimating UUSS Global embeddings statistics (KDE)...")
    # Menggunakan statistik ruang laten UUSS
    embeddings_3C_PDFs = utils.embedding_PDFs_3D(embedding_Z, embedding_N, embedding_E)

    #===================================================================
    #                            3. EVALUATION
    #===================================================================
    total_true_3C, total_pred_3C = [], []
    num_points = int(INPUT_WIN * SAMPLING_RATE)
    keys_list = list(test_data.keys())

    logger.info(f"Memproses {len(keys_list)} data UUSS...")

    for i in tqdm(range(len(keys_list)), desc="Inference UUSS"):
        record_key = keys_list[i]
        record = test_data[record_key]
        quake_label = record["type"] # label asli: 'le'
    
        try:
            # Sinyal & Noise 3C
            Z_n, N_n, E_n = record["Z_noise"][-num_points:], record["N_noise"][-num_points:], record["E_noise"][-num_points:]
            Z_s, N_s, E_s = record["Z"][:num_points], record["N"][:num_points], record["E"][:num_points]

            # Embeddings
            _in_Zn, _in_Nn, _in_En = utils.latent_codes_1D(Z_n, embedding_model), utils.latent_codes_1D(N_n, embedding_model), utils.latent_codes_1D(E_n, embedding_model)
            _in_Zs, _in_Ns, _in_Es = utils.latent_codes_1D(Z_s, embedding_model), utils.latent_codes_1D(N_s, embedding_model), utils.latent_codes_1D(E_s, embedding_model)

            # Inferensi 3C KDE - Noise
            emb_n_3c = np.array([_in_En, _in_Nn, _in_Zn]).reshape(1,-1)
            p_n_3c, _, _ = utils.infer_3C_PDFs(emb_n_3c, embeddings_3C_PDFs, "Kernel")
            
            # Inferensi 3C KDE - Earthquake
            emb_s_3c = np.array([_in_Es, _in_Ns, _in_Zs]).reshape(1,-1)
            p_s_3c, _, _ = utils.infer_3C_PDFs(emb_s_3c, embeddings_3C_PDFs, "Kernel")

            # Mapping Label STEAD (Biner: NO vs LE)
            # Di STEAD, output model index 1 (QB) atau 2 (LE) dianggap sebagai Earthquake (1)
            total_true_3C.extend([0, 1]) 
            total_pred_3C.extend([1 if p_n_3c >= 1 else 0, 1 if p_s_3c >= 1 else 0])
            
        except Exception as e:
            logger.error(f"Error pada {record_key}: {e}")
            continue

    #===================================================================
    #                        4. METRICS & SAVE
    #===================================================================
    matrix_3C, metrics_3C = utils.calc_confusion_metrics(total_true_3C, total_pred_3C)
    
    # Visualisasi
    fig_3C = utils.plot_confusion(f"{MODEL_TAG} {DATA_TAG} 3C", true_labels, matrix_3C, metrics_3C)
    fig_3C.savefig(os.path.join(save_dir, "UUSS_domain_3C_KDE.jpg"), dpi=300)
    
    dataset.save_json_data(os.path.join(save_dir, "indonesia_domain_3C_metrics.json"), metrics_3C)
    
    # Plot comprehensive metrics
    plot_comprehensive_metrics(metrics_3C, os.path.join(save_dir, "indonesia_domain_3C_metrics_bar.jpg"))

    logger.info("\n" + "="*40)
    logger.info(f"INDONESIA DOMAIN 3C ACCURACY: {metrics_3C.get('accuracy (avg.)')}")
    logger.info(f"INDONESIA DOMAIN 3C F1-SCORE: {metrics_3C.get('f1-score (avg.)')}")
    logger.info("="*40)
    logger.info("Pengujian Indonesia_domain_3C Selesai.")
# Out:
# [INFO] Memuat Dataset UUSS: extracted_data_3c_sesi_clean.json
# 2026-07-29 17:26:50.721493: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2026-07-29 17:26:50.721513: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2026-07-29 17:26:50.721522: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.66 GB
# 2026-07-29 17:26:50.721724: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-07-29 17:26:50.722038: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Estimating UUSS Global embeddings statistics (KDE)...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 109
#     105     embedding_E = dataset.load_embedding_data(EMB_DIR, "Embedding data, E.json")
#     106
#     107     logger.info(f"Estimating UUSS Global embeddings statistics (KDE)...")
#     108     # Menggunakan statistik ruang laten UUSS
# --> 109     embeddings_3C_PDFs = utils.embedding_PDFs_3D(embedding_Z, embedding_N, embedding_E)
#     110
#     111     #===================================================================
#     112     #                            3. EVALUATION
#
# File /Volumes/Local Disk/Code_Git/S3_code/seismic/mcu_quake/code_gen_trying/indonesia_jaya_benchmarking_data/mulai_juli/Library/utils.py:112, in embedding_PDFs_3D(embedding_Z, embedding_N, embedding_E, source_list)
#     110 # build embedding samples
#     111 for source_label in source_list:
# --> 112     values_Z = np.array(embedding_Z[source_label])
#     113     values_N = np.array(embedding_N[source_label])
#     114     values_E = np.array(embedding_E[source_label])
#
# KeyError: 'qb'

# %%
# -*- coding: utf-8 -*- sesi 2
from Library import utils, dataset
import os
from tensorflow import keras
from tqdm import tqdm
import numpy as np
from datetime import datetime
import logging
import matplotlib.pyplot as plt

# Fungsi untuk membuat diagram batang metrik komprehensif
def plot_comprehensive_metrics(metrics, save_path):
    # Mapping nama label ke key yang tepat sesuai output Anda
    labels = ['Accuracy', 'Recall', 'Precision', 'FPR', 'F1-Score']
    keys = [
        'Accuracy (avg.)', 
        'True positive rate (avg.)', 
        'Positive predictive value (avg.)', 
        'False positive rate (avg.)', 
        'F1-score (avg.)'
    ]
    
    # Mengambil nilai berdasarkan key yang tepat
    values = [metrics.get(k, 0) for k in keys]
    
    print(f"[DEBUG] Nilai yang akan diplot: {values}") 

    plt.figure(figsize=(12, 6))
    bars = plt.bar(labels, values, color=['#2c3e50', '#3498db', '#e67e22', '#e74c3c', '#27ae60'])
    
    plt.ylim(0, 1.0)
    plt.ylabel('Score')
    plt.title('Performance Metrics Evaluation (Average)')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    
    # Tambahkan angka di atas batang
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 0.01,
                f'{height:.3f}', ha='center', va='bottom')
                
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    plt.close()
    print(f"[INFO] Grafik metrik komprehensif tersimpan di: {save_path}")

# Main execution
if __name__ == "__main__":


    #===================================================================
    #                    1. KONFIGURASI PATH STEAD
    #===================================================================
    # Path dataset STEAD yang Bapak berikan
    #KEY_DATA_DIR = '/Volumes/Extreme SSD/json_indonesia_juli_sesi_4'
    #KEY_TEST_FILE = 'extracted_data_3c_4.json'
    #KEY_TEST_FILE = 'extracted_data_3c_4_NOFILTER.json'
    #KEY_TEST_FILE = 'extracted_data_3c_4_CLEAN.json'
    #KEY_TEST_FILE = 'extracted_data_3c_4_final.json'

    #KEY_DATA_DIR = '/Volumes/Local Disk/Code_Git/S3_code/seismic/mcu_quake/code_gen_trying/indonesia_jaya_benchmarking_data/mcquake_ori_file/Benchmark_ UUSS 3C_ test n2222 r100'
    #KEY_TEST_FILE = 'UUSS 3C data, test n2222 r100.json'

    KEY_DATA_DIR = "/Volumes/Extreme SSD/json_indonesia_juli_sesi_5"
    KEY_TEST_FILE = "extracted_data_3c_sesi_clean.json"



    DATA_TAG = "INDONESIA_DOMAIN"
    MODEL_TAG = "MCU_Quake_3C"
    INPUT_WIN = 7 
    SAMPLING_RATE = 100
    
    # STEAD fokus pada Noise (NO) dan Earthquake (LE)
    true_labels = ["NO", "LE"]
    source_to_code = {"noise": 0, "le": 1}

    # Path Model dan Embedding 
    BASE_REP = "/Volumes/Local Disk/Code_Git/S3_code/seismic/mcu_quake/code_gen_trying/indonesia_jaya_benchmarking_data/mulai_juli/mcquake_ori_file/Code & Figure demo"
    MODEL_PATH = os.path.join(BASE_REP, "Pre-trained model/MCU-Quake 5-20")
    
    # Path Embedding Khusus STEAD (n=61099) atau UUSS (n=11275) opsi: gunakan salah satu, jangan keduanya
    #EMB_DIR = os.path.join(BASE_REP, "Typical embedding/Embedding_data train 3C, STEAD norm7 mag3 L n61099, 30172538")
    #EMB_DIR = os.path.join(BASE_REP, "Typical embedding/Embedding_data train 3C, UUSS n11275 std15, 30120909")
    EMB_DIR = "/Volumes/Extreme SSD/unduhan_waveform_geofon/output/indonesia_domain_embeddings_3c_le"
    #===================================================================
    #                           2. PREPARE FILES
    #===================================================================
    print(f"[INFO] Memuat Dataset UUSS: {KEY_TEST_FILE}")
    test_data = dataset.load_json_data(os.path.join(KEY_DATA_DIR, KEY_TEST_FILE))
    
    SAVE_BASE = '/Volumes/Extreme SSD/json_indonesia_juli_sesi_5/output/nUUSS_embedding_3c_5a_final_clean'
    now = datetime.now()
    time_str = now.strftime("%d%H%M%S")
    save_dir = os.path.join(SAVE_BASE, f"{MODEL_TAG}_{DATA_TAG}_{time_str}")
    if not os.path.exists(save_dir): os.makedirs(save_dir)

    # Logger
    log_file_path = os.path.join(save_dir, "task_log_uuss_global.txt")
    logging.basicConfig(filename=log_file_path, level=logging.INFO, filemode='w',
                        format='%(asctime)s - [%(levelname)s]: %(message)s')
    logger = logging.getLogger()
    logger.addHandler(logging.StreamHandler())

    # Load Model & Embeddings STEAD
    embedding_model = keras.models.load_model(filepath=MODEL_PATH)
    embedding_Z = dataset.load_embedding_data(EMB_DIR, "Embedding data, Z.json")
    embedding_N = dataset.load_embedding_data(EMB_DIR, "Embedding data, N.json")
    embedding_E = dataset.load_embedding_data(EMB_DIR, "Embedding data, E.json")

    logger.info(f"Estimating UUSS Global embeddings statistics (KDE)...")
    # Menggunakan statistik ruang laten UUSS (Hanya memuat Noise dan LE)
    embeddings_3C_PDFs = utils.embedding_PDFs_3D(embedding_Z, embedding_N, embedding_E, source_list=['noise', 'le'])

    #===================================================================
    #                            3. EVALUATION
    #===================================================================
    total_true_3C, total_pred_3C = [], []
    num_points = int(INPUT_WIN * SAMPLING_RATE)
    keys_list = list(test_data.keys())

    logger.info(f"Memproses {len(keys_list)} data UUSS...")

    for i in tqdm(range(len(keys_list)), desc="Inference UUSS"):
        record_key = keys_list[i]
        record = test_data[record_key]
        quake_label = record["type"] # label asli: 'le'
    
        try:
            # Sinyal & Noise 3C
            Z_n, N_n, E_n = record["Z_noise"][-num_points:], record["N_noise"][-num_points:], record["E_noise"][-num_points:]
            Z_s, N_s, E_s = record["Z"][:num_points], record["N"][:num_points], record["E"][:num_points]

            # Embeddings
            _in_Zn, _in_Nn, _in_En = utils.latent_codes_1D(Z_n, embedding_model), utils.latent_codes_1D(N_n, embedding_model), utils.latent_codes_1D(E_n, embedding_model)
            _in_Zs, _in_Ns, _in_Es = utils.latent_codes_1D(Z_s, embedding_model), utils.latent_codes_1D(N_s, embedding_model), utils.latent_codes_1D(E_s, embedding_model)

            # Inferensi 3C KDE - Noise
            emb_n_3c = np.array([_in_En, _in_Nn, _in_Zn]).reshape(1,-1)
            p_n_3c, _, _ = utils.infer_3C_PDFs(emb_n_3c, embeddings_3C_PDFs, "Kernel")
            
            # Inferensi 3C KDE - Earthquake
            emb_s_3c = np.array([_in_Es, _in_Ns, _in_Zs]).reshape(1,-1)
            p_s_3c, _, _ = utils.infer_3C_PDFs(emb_s_3c, embeddings_3C_PDFs, "Kernel")

            # Mapping Label STEAD (Biner: NO vs LE)
            # Di STEAD, output model index 1 (QB) atau 2 (LE) dianggap sebagai Earthquake (1)
            total_true_3C.extend([0, 1]) 
            total_pred_3C.extend([1 if p_n_3c >= 1 else 0, 1 if p_s_3c >= 1 else 0])
            
        except Exception as e:
            logger.error(f"Error pada {record_key}: {e}")
            continue

    #===================================================================
    #                        4. METRICS & SAVE
    #===================================================================
    matrix_3C, metrics_3C = utils.calc_confusion_metrics(total_true_3C, total_pred_3C)
    
    # Visualisasi
    fig_3C = utils.plot_confusion(f"{MODEL_TAG} {DATA_TAG} 3C", true_labels, matrix_3C, metrics_3C)
    fig_3C.savefig(os.path.join(save_dir, "UUSS_domain_3C_KDE.jpg"), dpi=300)
    
    dataset.save_json_data(os.path.join(save_dir, "indonesia_domain_3C_metrics.json"), metrics_3C)
    
    # Plot comprehensive metrics
    plot_comprehensive_metrics(metrics_3C, os.path.join(save_dir, "indonesia_domain_3C_metrics_bar.jpg"))

    logger.info("\n" + "="*40)
    logger.info(f"INDONESIA DOMAIN 3C ACCURACY: {metrics_3C.get('Accuracy (avg.)')}")
    logger.info(f"INDONESIA DOMAIN 3C F1-SCORE: {metrics_3C.get('F1-score (avg.)')}")
    logger.info("="*40)
    logger.info("Pengujian Indonesia_domain_3C Selesai.")
# Out:
# [INFO] Memuat Dataset UUSS: extracted_data_3c_sesi_clean.json
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Estimating UUSS Global embeddings statistics (KDE)...
# Estimating UUSS Global embeddings statistics (KDE)...
# Estimating UUSS Global embeddings statistics (KDE)...
# Estimating UUSS Global embeddings statistics (KDE)...
# Memproses 5159 data UUSS...
# Memproses 5159 data UUSS...
# Memproses 5159 data UUSS...
# Memproses 5159 data UUSS...
# Inference UUSS: 100%|██████████| 5159/5159 [01:50<00:00, 46.55it/s]
#
# ========================================
#
# ========================================
#
# ========================================
#
# ========================================
# INDONESIA DOMAIN 3C ACCURACY: 0.8546229889513471
# INDONESIA DOMAIN 3C ACCURACY: 0.8546229889513471
# INDONESIA DOMAIN 3C ACCURACY: 0.8546229889513471
# INDONESIA DOMAIN 3C ACCURACY: 0.8546229889513471
# INDONESIA DOMAIN 3C F1-SCORE: 0.8525203609949373
# INDONESIA DOMAIN 3C F1-SCORE: 0.8525203609949373
# INDONESIA DOMAIN 3C F1-SCORE: 0.8525203609949373
# INDONESIA DOMAIN 3C F1-SCORE: 0.8525203609949373
# ========================================
# ========================================
# ========================================
# ========================================
# Pengujian Indonesia_domain_3C Selesai.
# Pengujian Indonesia_domain_3C Selesai.
# Pengujian Indonesia_domain_3C Selesai.
# Pengujian Indonesia_domain_3C Selesai.
# Accuracy: [0.8546229889513471, 0.8546229889513471]
# Accuracy (avg.): 0.8546229889513471
# True positive rate: [0.7352200038767203, 0.974025974025974]
# True positive rate (avg.): 0.8546229889513471
# True negative rate: [0.974025974025974, 0.7352200038767203]
# True negative rate (avg.): 0.8546229889513471
# Positive predictive value: [0.965877259994907, 0.7862619308402441]
# Positive predictive value (avg.): 0.8760695954175756
# Negative predictive value: [0.7862619308402441, 0.965877259994907]
# Negative predictive value (avg.): 0.8760695954175756
# False positive rate: [0.025974025974025976, 0.2647799961232797]
# False positive rate (avg.): 0.1453770110486528
# False negative rate: [0.2647799961232797, 0.025974025974025976]
# False negative rate (avg.): 0.1453770110486528
# False discovery rate: [0.034122740005092946, 0.2137380691597559]
# False discovery rate (avg.): 0.12393040458242444
# F1-score: [0.8349108518600045, 0.8701298701298702]
# F1-score (avg.): 0.8525203609949373
# [DEBUG] Nilai yang akan diplot: [0.8546229889513471, 0.8546229889513471, 0.8760695954175756, 0.1453770110486528, 0.8525203609949373]
# [INFO] Grafik metrik komprehensif tersimpan di: /Volumes/Extreme SSD/json_indonesia_juli_sesi_5/output/nUUSS_embedding_3c_5a_final_clean/MCU_Quake_3C_INDONESIA_DOMAIN_29174321/indonesia_domain_3C_metrics_bar.jpg
