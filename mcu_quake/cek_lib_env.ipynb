# %%
import sys
import os

# Path ke folder Root (tempat folder Library berada)
ROOT_PATH = "/Volumes/Local Disk/Code_Git/S3_code/seismic/mcu_quake/rep_code/"

# Masukkan ROOT_PATH ke sys.path
if ROOT_PATH not in sys.path:
    sys.path.append(ROOT_PATH)

# Sekarang Anda bisa mengimpor dengan merujuk nama foldernya
try:
    from Library.model import Embedding_Network
    from Library.dataset import Data_Generator
    print("✅ Modul Library berhasil diimpor!")
except ImportError as e:
    print(f"❌ Masih gagal import: {e}")
    print("\nPath yang sedang diperiksa Python:")
    for p in sys.path:
        print(p)
# Out:
# ✅ Modul Library berhasil diimpor!

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.8.0
